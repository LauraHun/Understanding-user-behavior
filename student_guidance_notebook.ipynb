# %% [markdown]
# # STUDENT GUIDANCE NOTEBOOK – TO BE COMPLETED BY STUDENTS
# # This notebook provides a STRUCTURE and GUIDELINES.
# # It does NOT contain solutions.
#
# # -------------------------------------------------
# # FUNDAMENTAL RULE
# # -------------------------------------------------
# # You must implement the analyses, statistical tests, and models yourself.
# # Every methodological and analytical choice must be justified in the final report.
#
# # -------------------------------------------------
# # 1. Data loading and understanding
# # -------------------------------------------------
# # TODO:
# # - Load the provided CSV files
# # - Identify join keys between datasets
# # - Classify variables (subjective, behavioral, experimental)
#
# # Question:
# # Which datasets provide access to user experience versus observed behavior?
#
# # -------------------------------------------------
# # 2. Exploratory analysis of questionnaires
# # -------------------------------------------------
# # TODO:
# # - Produce relevant descriptive statistics
# # - Visualize at least two psychological dimensions
#
# # Question:
# # What do these scores suggest about usability and cognitive load?
#
# # -------------------------------------------------
# # 3. UX hypotheses formulation
# # -------------------------------------------------
# # TODO:
# # - Formulate 2–3 testable hypotheses
# # - Identify the corresponding variables in the data
#
# # -------------------------------------------------
# # 4. Experimental design & A/B testing
# # -------------------------------------------------
# # TODO:
# # - Separate sessions by interface version (A vs. B)
# # - Choose appropriate statistical tests
# # - Check assumptions and validity conditions
#
# # Question:
# # Which conclusions are legitimate from a managerial perspective?
#
# # -------------------------------------------------
# # 5. Behavioral analysis (logs)
# # -------------------------------------------------
# # From the raw interaction traces in logs.csv, analyze how users actually interact
# # with the system.
# #
# # TODO:
# # - Explore temporal structure and action types
# # - Identify repetitions, errors, and potential sequences
# # - Begin thinking about meaningful behavioral indicators
#
# # Question:
# # Which observed behaviors are compatible with effective decision-making?
#
# # -------------------------------------------------
# # 6. Feature engineering from logs
# # -------------------------------------------------
# # Objective: construct BEHAVIORAL INDICATORS AT THE SESSION LEVEL.
# # These indicators will be used for comparative analysis and/or modeling.
# #
# # PROVIDED EXAMPLES (illustrative only, not sufficient):
# # - Usage intensity: total number of actions per session
# # - Interaction difficulty: proportion of actions flagged as errors per session
# #
# # TODO (MANDATORY):
# # - Implement the two example indicators above
# # - Propose AT LEAST 3 additional indicators
# # - For each indicator, document:
# #   * what it measures
# #   * the theoretical concept it relates to (e.g., cognitive load, exploration, hesitation)
# #   * its limitations
#
# # -------------------------------------------------
# # 7. Modeling and/or segmentation
# # -------------------------------------------------
# # TODO:
# # - Choose at least two different models or segmentation approaches
# # - Implement appropriate validation strategies
# # - Compare models using relevant metrics
#
# # Question:
# # In which situations does the model fail, and why?
#
# # -------------------------------------------------
# # 8. Interpretation and explainability
# # -------------------------------------------------
# # TODO:
# # - Identify the most influential behavioral indicators
# # - Discuss the level of confidence that can be placed in the models
#
# # -------------------------------------------------
# # 9. Managerial synthesis
# # -------------------------------------------------
# # TODO:
# # - Integrate UX, behavioral, and modeling results
# # - Formulate a clear and well-argued managerial recommendation
#
# # FINAL QUESTION:
# # If you were the manager, what decision would you make based on this analysis?
